# %%
import pandas as pd

# %%
cf_full = pd.read_csv("/Users/pippalin/Desktop/probing_llm/data/dime_recipients_1979_2024.csv")
# Out:
# /var/folders/qd/nfpzqtz54rx879c00hvvjfyw0000gn/T/ipykernel_37810/991431888.py:1: DtypeWarning: Columns (10,12,15,16,17,41,43,44,45,47,49,50,54,55,58,59,60,61,63) have mixed types. Specify dtype option on import or set low_memory=False.
#   cf_full = pd.read_csv("/Users/pippalin/Desktop/probing_llm/data/dime_recipients_1979_2024.csv")

# %%
cf_full[cf_full["name"] == "murphy, christopher s"]["recipient.cfscore"]
# Out:
# 58986    -1.006
# 65284    -1.006
# 72458    -1.006
# 76382    -1.006
# 100273   -1.006
# 100274   -1.006
# 100275   -1.006
# Name: recipient.cfscore, dtype: float64

# %%
cf
# Out:
#       election  cycle  fecyear    bonica.rid    bonica.cid  \
# 0       fd2020   2020     2020  comm69042345           NaN
# 1       fd2020   2020     2020  comm69042414           NaN
# 2       fd2020   2020     2020  comm69042450           NaN
# 3       fd2020   2020     2020  comm69042426           NaN
# 4       fd2020   2020     2020  comm69042427           NaN
# ...        ...    ...      ...           ...           ...
# 24589   AZ2020   2020     2020    cand145013  3.715988e+10
# 24590   AZ2020   2020     2020    cand143094  5.000040e+15
# 24591   KY2020   2020     2020     cand63711  3.065023e+09
# 24592   UT2020   2020     2020    cand145274  5.000000e+15
# 24593   FL2020   2020     2020    cand152874           NaN
#
#                                  name             lname  ffname   fname mname  \
# 0      idahoans for a fair wage, inc.               NaN     NaN     NaN   NaN
# 1      young democrats of atlanta inc               NaN     NaN     NaN   NaN
# 2         humanity first for illinois               NaN     NaN     NaN   NaN
# 3           don hill for congress inc               NaN     NaN     NaN   NaN
# 4                      petel4congress               NaN     NaN     NaN   NaN
# ...                               ...               ...     ...     ...   ...
# 24589                     pace, tyler              pace   tyler   tyler   NaN
# 24590           marquez peterson, lea  marquez peterson     lea     lea   NaN
# 24591                   thayer, damon            thayer   damon   damon   NaN
# 24592                  garbett, jan v           garbett   jan v     jan     v
# 24593                   lyles, tamika             lyles  tamika  tamika   NaN
#
#        ...          FEC.ID         NID  before.switch.ICPSR  \
# 0      ...  527o:833544585         NaN                  NaN
# 1      ...  527o:843410393         NaN                  NaN
# 2      ...  527o:844864691         NaN                  NaN
# 3      ...  527o:844096305         NaN                  NaN
# 4      ...  527o:844119549         NaN                  NaN
# ...    ...             ...         ...                  ...
# 24589  ...             NaN  AZ45362003                  NaN
# 24590  ...             NaN   AZ8558474                  NaN
# 24591  ...             NaN   KY6656549                  NaN
# 24592  ...             NaN  UT18166344                  NaN
# 24593  ...             NaN  FL49845624                  NaN
#
#       after.switch.ICPSR  party.orig nimsp.party nimsp.candidate.ICO.code  \
# 0                    NaN         NaN         NaN                      NaN
# 1                    NaN         NaN         NaN                      NaN
# 2                    NaN         NaN         NaN                      NaN
# 3                    NaN         NaN         NaN                      NaN
# 4                    NaN         NaN         NaN                      NaN
# ...                  ...         ...         ...                      ...
# 24589                NaN  REPUBLICAN  REPUBLICAN                        I
# 24590                NaN  REPUBLICAN  REPUBLICAN                        I
# 24591                NaN  REPUBLICAN  REPUBLICAN                        I
# 24592                NaN  REPUBLICAN  REPUBLICAN                        O
# 24593                NaN  DEMOCRATIC  DEMOCRATIC                        O
#
#                        nimsp.district                    nimsp.office  \
# 0                                 NaN                             NaN
# 1                                 NaN                             NaN
# 2                                 NaN                             NaN
# 3                                 NaN                             NaN
# 4                                 NaN                             NaN
# ...                               ...                             ...
# 24589             senate district 025                          senate
# 24590        corporation commissioner        corporation commissioner
# 24591             senate district 017                          senate
# 24592  governor / lieutenant governor  governor / lieutenant governor
# 24593              house district 043                           house
#
#        nimsp.candidate.status
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 24589             Won-General
# 24590             Won-General
# 24591             Won-General
# 24592    Disqualified-Primary
# 24593            Lost-Primary
#
# [24594 rows x 64 columns]
